# %% [markdown]
# ## Getting Started
#
# - Download MapPLUTO data from [NYC DCP](https://s-media.nyc.gov/agencies/dcp/assets/files/zip/data-tools/bytes/nyc_mappluto_24v1_1_shp.zip)
# - Unzip the file and place contents in the `Data` directory at the root of this repo
# - Make sure you have installed all requisite libraries by running `pip install -r requirements.txt` **_with your virtual environment activated_**
#
# ## Goals
#
# - Load data from file
# - Explore spatial and non-spatial elements of the dataset
# - Compare tradeoffs between different methods of loading data
# - Demonstrate tradeoffs in different file formats

# %%
# the bare minimum
import matplotlib.pyplot as plt
import geopandas as gpd

# more advanced
import pyogrio as ogr
from sklearn.cluster import KMeans
from lonboard import Map, PolygonLayer
from lonboard.colormap import apply_categorical_cmap, apply_continuous_cmap
from palettable.colorbrewer.sequential import PuRd_9
from matplotlib.colors import LogNorm

import pydeck as pdk

# %% [markdown]
# # load PLUTO data

# %%
# pluto = gpd.read_file("../Data/nyc_mappluto_24v1_1_shp/MapPLUTO.shp")

# %%
pluto_ogrio = ogr.read_dataframe("../Data/nyc_mappluto_24v1_1_shp/MapPLUTO.shp")

# %% [markdown]
# # basic exploration

# %%
pluto_ogrio.columns
# Out:
# Index(['Borough', 'Block', 'Lot', 'CD', 'BCT2020', 'BCTCB2020', 'CT2010',
#        'CB2010', 'SchoolDist', 'Council', 'ZipCode', 'FireComp', 'PolicePrct',
#        'HealthCent', 'HealthArea', 'Sanitboro', 'SanitDistr', 'SanitSub',
#        'Address', 'ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4',
#        'Overlay1', 'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight',
#        'SplitZone', 'BldgClass', 'LandUse', 'Easements', 'OwnerType',
#        'OwnerName', 'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea',
#        'RetailArea', 'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea',
#        'AreaSource', 'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal',
#        'LotFront', 'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode',
#        'IrrLotCode', 'LotType', 'BsmtCode', 'AssessLand', 'AssessTot',
#        'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
#        'Landmark', 'BuiltFAR', 'ResidFAR', 'CommFAR', 'FacilFAR', 'BoroCode',
#        'BBL', 'CondoNo', 'Tract2010', 'XCoord', 'YCoord', 'ZoneMap', 'ZMCode',
#        'Sanborn', 'TaxMap', 'EDesigNum', 'APPBBL', 'APPDate', 'PLUTOMapID',
#        'FIRM07_FLA', 'PFIRM15_FL', 'Version', 'DCPEdited', 'Latitude',
#        'Longitude', 'Notes', 'Shape_Leng', 'Shape_Area', 'geometry'],
#       dtype='object')

# %%
pluto_ogrio.dtypes
# Out:
# Borough         object
# Block            int64
# Lot              int32
# CD               int32
# BCT2020         object
#                 ...
# Longitude      float64
# Notes           object
# Shape_Leng     float64
# Shape_Area     float64
# geometry      geometry
# Length: 95, dtype: object

# %% [markdown]
# ## categorical column

# %%
pluto_ogrio.GarageArea.value_counts()
# Out:
# GarageArea
# 0         846668
# 5000         188
# 2500         176
# 200          151
# 400          137
#            ...
# 847938         1
# 36904          1
# 1637           1
# 108420         1
# 1933           1
# Name: count, Length: 4203, dtype: int64

# %% [markdown]
# ## Your turn:
#
# - How many lots of each land use type are there?
#   - Use `groupby` to determine the number of lots of each land use type
# - What is the lot area of each land use type?
#   - Use `groupby` to make a bar chart that shows the average lot area of each land use type
# - Can you find the total number of lots that contain `Commercial & Office Buildings` in the Bronx?
#   - use groupby on multiple columns to achieve this
# - Can you find the share of each land use type in each borough?

# %%
pluto_ogrio.groupby("GarageArea").LotArea.sum()
# Out:
# GarageArea
# 0          6251739192
# 1              486421
# 9                5029
# 10              62113
# 28              19833
#               ...
# 960000        7492320
# 998000       29305534
# 1119947        905000
# 1500000        255000
# 2677430     214378390
# Name: LotArea, Length: 4203, dtype: int64

# %% [markdown]
# ## Okay, now let's look at lot and building area

# %%
pluto_ogrio.groupby("LandUse").LotArea.sum().sort_values(ascending=False).plot.bar()
plt.title("Total lot area by land use type")
# Out:
# Text(0.5, 1.0, 'Total lot area by land use type')

# %%
# now the same but for building area
pluto_ogrio.groupby("LandUse").BldgArea.sum().sort_values(ascending=False).plot.bar()
plt.title("Total building area by land use type")
# Out:
# Text(0.5, 1.0, 'Total building area by land use type')

# %%
# plot both lot and building area on the same plot with a secondary y-axis
fig, ax = plt.subplots()
by_lot_area = pluto_ogrio.groupby("LandUse").LotArea.sum().sort_values(ascending=False)

by_lot_area.plot.bar(ax=ax, color="red")

# get order to apply below
order = {v: i for i, v in enumerate(by_lot_area.index)}

ax.set_ylabel("Lot Area")
ax.set_xlabel("Land Use Type")

ax2 = ax.twinx()
pluto_ogrio.groupby("LandUse").BldgArea.sum().reindex(by_lot_area.index).plot.bar(
    ax=ax2, edgecolor="black", color="none"
)
ax2.set_ylabel("Building Area")

plt.title("Total lot and building area by land use type")

# add legends
ax.legend(["Lot Area"], loc="upper left")
ax2.legend(["Building Area"], loc="upper right")

# %% [markdown]
# ## numeric column

# %%
pluto_ogrio["NumFloors"].describe()
# Out:
# count    856819.000000
# mean          2.357554
# std           2.012707
# min           0.000000
# 25%           2.000000
# 50%           2.000000
# 75%           2.500000
# max         104.000000
# Name: NumFloors, dtype: float64

# %%
pluto_ogrio["NumFloors"].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Your turn:
#
# - make a histogram for each borough like above
# - then, choose another chart type to visualize the distribution of lot area for each borough. See [here](https://matplotlib.org/stable/plot_types/index.html) for some built in options in matplotlib, or here for [seaborn](https://seaborn.pydata.org/tutorial/distributions.html)

# %% [markdown]
# ## Ok, now let's make a boxplot to see how wide the range is within each boro's data

# %%
pluto_ogrio.boxplot(column="NumFloors", by="Borough")
# Out:
# <Axes: title={'center': 'NumFloors'}, xlabel='Borough'>

# %% [markdown]
# What does this distribution tell us about the number of floors in each borough?

# %% [markdown]
# # cluster by number of floors

# %%
# get clusters using kmeans

kmeans = KMeans(n_clusters=5)
kmeans.fit(pluto_ogrio[["NumFloors", "ResArea"]])

pluto_ogrio["NumFloorsCluster"] = kmeans.predict(pluto_ogrio[["NumFloors", "ResArea"]])

# %%
pluto_ogrio.groupby("NumFloorsCluster").NumFloors.describe().sort_values("max")
# Out:
#                      count       mean        std   min   25%   50%   75%  \
# NumFloorsCluster
# 2                      1.0  33.000000        NaN  33.0  33.0  33.0  33.0
# 4                      3.0  20.000000  11.269428  13.0  13.5  14.0  23.5
# 1                   5259.0  13.033704   9.923872   0.0   6.0  10.0  16.0
# 3                    402.0  23.879353  16.312365   0.0  13.0  20.0  33.0
# 0                 851154.0   2.281326   1.553347   0.0   2.0   2.0   2.5
#
#                     max
# NumFloorsCluster
# 2                  33.0
# 4                  33.0
# 1                  90.0
# 3                  98.0
# 0                 104.0

# %%
pluto_ogrio.plot.scatter(x="NumFloors", y="ResArea", c="NumFloorsCluster", cmap="tab10")
# Out:
# <Axes: xlabel='NumFloors', ylabel='ResArea'>

# %%
# same as above but with log y axis
pluto_ogrio.plot.scatter(
    x="NumFloors", y="ResArea", c="NumFloorsCluster", cmap="tab10", logy=True
)
# Out:
# <Axes: xlabel='NumFloors', ylabel='ResArea'>

# %%
pluto_ogrio["NumFloorsCluster"].plot.hist(bins=5, alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # and now, mapping

# %% [markdown]
# ## static map

# %%
pluto_ogrio.plot(figsize=(10, 10)).set_axis_off()
plt.title("NYC MapPLUTO")
# Out:
# Text(0.5, 1.0, 'NYC MapPLUTO')

# %%
cmap = {
    "One & Two Family Buildings": "#ff0000",
    "Multi-Family Walk-Up Buildings": "#00ff00",
    "Multi-Family Elevator Buildings": "#0000ff",
    "Mixed Residential & Commercial Buildings": "#ff00ff",
    "Commercial & Office Buildings": "#00ffff",
    "Industrial & Manufacturing": "#ffff00",
    "Transportation & Utility": "#808080",
    "Public Facilities & Institutions": "#800000",
    "Open Space & Outdoor Recreation": "#008000",
    "Parking Facilities": "#000080",
    "Vacant Land": "#800080",
    "Unknown": "#000000",
}

# %%
pluto_ogrio.fillna({"LandUse": "Unknown"}, inplace=True)

# %%
pluto_ogrio["color"] = pluto_ogrio["LandUse"].map(cmap)

# %%
ax = pluto_ogrio.plot(
    color=pluto_ogrio["color"],
    figsize=(10, 10),
    legend=True,
).set_axis_off()
plt.title("NYC MapPLUTO")


# populate legend items based on dict from above
legend_colors = [
    plt.Line2D([0], [0], marker="o", color="w", markerfacecolor=c, markersize=10)
    for c in cmap.values()
]
labels = cmap.keys()
plt.legend(legend_colors, labels, loc="upper left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ax = pluto_ogrio.plot(
#       2     color=pluto_ogrio["color"],
#       3     figsize=(10, 10),
#       4     legend=True,
#       5 ).set_axis_off()
#       6 plt.title("NYC MapPLUTO")
#       9 # populate legend items based on dict from above
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\geopandas\plotting.py:979, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     977 kind = kwargs.pop("kind", "geo")
#     978 if kind == "geo":
# --> 979     return plot_dataframe(data, *args, **kwargs)
#     980 if kind in self._pandas_kinds:
#     981     # Access pandas plots
#     982     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\geopandas\plotting.py:716, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     713     markersize = df[markersize].values
#     715 if column is None:
# --> 716     return plot_series(
#     717         df.geometry,
#     718         cmap=cmap,
#     719         color=color,
#     720         ax=ax,
#     721         figsize=figsize,
#     722         markersize=markersize,
#     723         aspect=aspect,
#     724         **style_kwds,
#     725     )
#     727 # To accept pd.Series and np.arrays as column
#     728 if isinstance(column, (np.ndarray, pd.Series)):
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\geopandas\plotting.py:470, in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     467         facecolor = color_
#     469     values_ = values[poly_idx] if cmap else None
# --> 470     _plot_polygon_collection(
#     471         ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     472     )
#     474 # plot all LineStrings and MultiLineString components in same collection
#     475 lines = expl_series[line_idx]
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\geopandas\plotting.py:184, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     180     kwargs["color"] = color
#     182 _expand_kwargs(kwargs, multiindex)
# --> 184 collection = PatchCollection([_PolygonPatch(poly) for poly in geoms], **kwargs)
#     186 if values is not None:
#     187     collection.set_array(np.asarray(values))
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\collections.py:1881, in PatchCollection.__init__(self, patches, match_original, **kwargs)
#    1878     kwargs['linestyles'] = [p.get_linestyle() for p in patches]
#    1879     kwargs['antialiaseds'] = [p.get_antialiased() for p in patches]
# -> 1881 super().__init__(**kwargs)
#    1883 self.set_paths(patches)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\collections.py:206, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     203 self._offset_transform = offset_transform
#     205 self._path_effects = None
# --> 206 self._internal_update(kwargs)
#     207 self._paths = None
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\artist.py:1192, in Artist._update_props(self, props, errfmt)
#    1189             if not callable(func):
#    1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
# -> 1192             ret.append(func(v))
#    1193 if ret:
#    1194     self.pchanged()
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\collections.py:784, in Collection.set_facecolor(self, c)
#     782     c = c.lower()
#     783 self._original_facecolor = c
# --> 784 self._set_facecolor(c)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\collections.py:766, in Collection._set_facecolor(self, c)
#     763 if c is None:
#     764     c = self._get_default_facecolor()
# --> 766 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     767 self.stale = True
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\colors.py:512, in to_rgba_array(c, alpha)
#     510         rgba = np.array([to_rgba(cc) for cc in c])
#     511 else:
# --> 512     rgba = np.array([to_rgba(cc) for cc in c])
#     514 if alpha is not None:
#     515     rgba[:, 3] = alpha
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\colors.py:309, in to_rgba(c, alpha)
#     307     rgba = None
#     308 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 309     rgba = _to_rgba_no_colorcycle(c, alpha)
#     310     try:
#     311         _colors_full_map.cache[c, alpha] = rgba
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\matplotlib\colors.py:398, in _to_rgba_no_colorcycle(c, alpha)
#     396 # tuple color.
#     397 if not np.iterable(c):
# --> 398     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     399 if len(c) not in [3, 4]:
#     400     raise ValueError("RGBA sequence should have length 3 or 4")
#
# ValueError: Invalid RGBA argument: nan

# %%
pluto_ogrio.plot(
    column="LandUse", figsize=(10, 10), legend=True, legend_kwds={"loc": "upper left"}
).set_axis_off()
plt.title("NYC MapPLUTO")
# Out:
# Text(0.5, 1.0, 'NYC MapPLUTO')

# %% [markdown]
# ## Your turn:
#
# - map a numeric column using a continuous colormap for Queens. See here for a list and discussion of colormaps: https://matplotlib.org/stable/tutorials/colors/colormaps.html
# - What patterns emerge?

# %% [markdown]
# # prep for interactive mapping

# %%
pluto_ogrio_wgs = pluto_ogrio.to_crs("epsg:4326")

# %% [markdown]
# ## visualize a categorical variable

# %%
cmap_rgb = {k: list(int(v[i : i + 2], 16) for i in (1, 3, 5)) for k, v in cmap.items()}

# %%
cmap_rgb
# Out:
# {'One & Two Family Buildings': [255, 0, 0],
#  'Multi-Family Walk-Up Buildings': [0, 255, 0],
#  'Multi-Family Elevator Buildings': [0, 0, 255],
#  'Mixed Residential & Commercial Buildings': [255, 0, 255],
#  'Commercial & Office Buildings': [0, 255, 255],
#  'Industrial & Manufacturing': [255, 255, 0],
#  'Transportation & Utility': [128, 128, 128],
#  'Public Facilities & Institutions': [128, 0, 0],
#  'Open Space & Outdoor Recreation': [0, 128, 0],
#  'Parking Facilities': [0, 0, 128],
#  'Vacant Land': [128, 0, 128],
#  'Unknown': [0, 0, 0]}

# %%
len(pluto_ogrio_wgs[pluto_ogrio_wgs["LandUse"].isna()])
# Out:
# 0

# %%
pluto_ogrio_wgs["LandUse"].fillna("Unknown", inplace=True)
# Out:
# C:\Users\fauxi\AppData\Local\Temp\ipykernel_10800\961482650.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   pluto_ogrio_wgs["LandUse"].fillna("Unknown", inplace=True)

# %% [markdown]
# ## uhoh- observe the above warning- re-write the code to avoid this

# %% [markdown]
# ## now, we can plot the data using lonboard to create an interactive map

# %%
df = pluto_ogrio_wgs[["LandUse", "geometry"]]

layer = PolygonLayer.from_geopandas(
    df[["LandUse", "geometry"]],
    get_fill_color=apply_continuous_cmap(normalized_floors, cmap=PuRd_9),
     extruded=True,
    get_elevation=pluto_ogrio_wgs["NumFloors"]
)
m = Map(layer)
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       1 df = pluto_ogrio_wgs[["LandUse", "geometry"]]
#       3 layer = PolygonLayer.from_geopandas(
#       4     df[["LandUse", "geometry"]],
# ----> 5     get_fill_color=apply_continuous_cmap(normalized_floors, cmap=PuRd_9),
#       6      extruded=True,
#       7     get_elevation=pluto_ogrio_wgs["NumFloors"]
#       8 )
#       9 m = Map(layer)
#      10 m
#
# NameError: name 'normalized_floors' is not defined

# %%
pluto_ogrio_wgs["LandUse"] = pluto_ogrio_wgs["LandUse"].astype("category")

# %%
df = pluto_ogrio_wgs[["LandUse", "geometry"]]

layer = PolygonLayer.from_geopandas(
    df[["LandUse", "geometry"]],
    get_fill_color=apply_categorical_cmap(df["LandUse"], cmap=cmap_rgb),
)
m = Map(layer)
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 5
#       1 df = pluto_ogrio_wgs[["LandUse", "geometry"]]
#       3 layer = PolygonLayer.from_geopandas(
#       4     df[["LandUse", "geometry"]],
# ----> 5     get_fill_color=apply_categorical_cmap(df["LandUse"], cmap=cmap_rgb),
#       6 )
#       7 m = Map(layer)
#       8 m
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\colormap.py:172, in apply_categorical_cmap(values, cmap, alpha)
#     169     lut[:, 3] = 255
#     171 for i, key in enumerate(values.dictionary):
# --> 172     color = cmap[key.as_py()]
#     173     if len(color) == 3:
#     174         lut[i, :3] = color
#
# KeyError: '01'

# %%
pluto_ogrio_wgs[pluto_ogrio_wgs.geometry.isna()]
# Out:
# Empty GeoDataFrame
# Columns: [Borough, Block, Lot, CD, BCT2020, BCTCB2020, CT2010, CB2010, SchoolDist, Council, ZipCode, FireComp, PolicePrct, HealthCent, HealthArea, Sanitboro, SanitDistr, SanitSub, Address, ZoneDist1, ZoneDist2, ZoneDist3, ZoneDist4, Overlay1, Overlay2, SPDist1, SPDist2, SPDist3, LtdHeight, SplitZone, BldgClass, LandUse, Easements, OwnerType, OwnerName, LotArea, BldgArea, ComArea, ResArea, OfficeArea, RetailArea, GarageArea, StrgeArea, FactryArea, OtherArea, AreaSource, NumBldgs, NumFloors, UnitsRes, UnitsTotal, LotFront, LotDepth, BldgFront, BldgDepth, Ext, ProxCode, IrrLotCode, LotType, BsmtCode, AssessLand, AssessTot, ExemptTot, YearBuilt, YearAlter1, YearAlter2, HistDist, Landmark, BuiltFAR, ResidFAR, CommFAR, FacilFAR, BoroCode, BBL, CondoNo, Tract2010, XCoord, YCoord, ZoneMap, ZMCode, Sanborn, TaxMap, EDesigNum, APPBBL, APPDate, PLUTOMapID, FIRM07_FLA, PFIRM15_FL, Version, DCPEdited, Latitude, Longitude, Notes, Shape_Leng, Shape_Area, geometry, NumFloorsCluster, color]
# Index: []
#
# [0 rows x 97 columns]

# %% [markdown]
# ## visualize a continuous variable

# %%
df = pluto_ogrio_wgs[["NumFloors", "geometry"]]

normalizer = LogNorm(1, df.NumFloors.max(), clip=True)
normalized_floors = normalizer(df.NumFloors)

layer = PolygonLayer.from_geopandas(
    df[["NumFloors", "geometry"]],
    get_fill_color=apply_continuous_cmap(normalized_floors, cmap=PuRd_9),
     extruded=True,
    get_elevation=pluto_ogrio_wgs["NumFloors"]*5
)
m = Map(layer)
m
# Out:
# Map(layers=[PolygonLayer(extruded=True, get_elevation=<pyarrow.lib.FloatArray object at 0x0000023DA5116320>
# [
# …

# %%
df = pluto_ogrio_wgs[pluto_ogrio_wgs.YearBuilt > 2010][["NumFloors", "geometry"]]

normalizer = LogNorm(1, df.NumFloors.max(), clip=True)
normalized_floors = normalizer(df.NumFloors)

layer = PolygonLayer.from_geopandas(
    df[["NumFloors", "geometry"]],
    get_fill_color=apply_continuous_cmap(normalized_floors, cmap=PuRd_9),
     extruded=True,
    get_elevation=pluto_ogrio_wgs["NumFloors"]*5
)
m = Map(layer)
m
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In[35], line 6
#       3 normalizer = LogNorm(1, df.NumFloors.max(), clip=True)
#       4 normalized_floors = normalizer(df.NumFloors)
# ----> 6 layer = PolygonLayer.from_geopandas(
#       7     df[["NumFloors", "geometry"]],
#       8     get_fill_color=apply_continuous_cmap(normalized_floors, cmap=PuRd_9),
#       9      extruded=True,
#      10     get_elevation=pluto_ogrio_wgs["NumFloors"]*5
#      11 )
#      12 m = Map(layer)
#      13 m
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\_layer.py:724, in PolygonLayer.from_geopandas(cls, gdf, auto_downcast, **kwargs)
#     716 @classmethod
#     717 def from_geopandas(
#     718     cls,
#    (...)
#     722     **kwargs: Unpack[PolygonLayerKwargs],
#     723 ) -> Self:
# --> 724     return super().from_geopandas(gdf=gdf, auto_downcast=auto_downcast, **kwargs)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\_layer.py:334, in BaseArrowLayer.from_geopandas(cls, gdf, auto_downcast, **kwargs)
#     331     gdf = _auto_downcast(gdf.copy())  # type: ignore
#     333 table = geopandas_to_geoarrow(gdf)
# --> 334 return cls(table=table, **kwargs)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\_layer.py:714, in PolygonLayer.__init__(self, table, _rows_per_chunk, **kwargs)
#     707 def __init__(
#     708     self,
#     709     *,
#    (...)
#     712     **kwargs: Unpack[PolygonLayerKwargs],
#     713 ):
# --> 714     super().__init__(table=table, _rows_per_chunk=_rows_per_chunk, **kwargs)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\_layer.py:302, in BaseArrowLayer.__init__(self, table, _rows_per_chunk, **kwargs)
#     298     raise ValueError("Cannot serialize table with 0 rows per chunk.")
#     300 self._rows_per_chunk = rows_per_chunk
# --> 302 super().__init__(table=table, **kwargs)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\_layer.py:87, in BaseLayer.__init__(self, extensions, **kwargs)
#      80 def __init__(self, *, extensions: Sequence[BaseExtension] = (), **kwargs):
#      81     # We allow layer extensions to dynamically inject properties onto the layer
#      82     # widgets where the layer is defined. We wish to allow extensions and their
#      83     # properties to be passed in the layer constructor. _However_, if
#      85     extension_kwargs = remove_extension_kwargs(extensions, kwargs)
# ---> 87     super().__init__(extensions=extensions, **kwargs)
#      89     # Dynamically set layer traits from extensions after calling __init__
#      90     self._add_extension_traits(extensions)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\_base.py:25, in BaseWidget.__init__(self, **kwargs)
#      22     if provided_trait_name not in layer_trait_names:
#      23         raise TypeError(msg.format(provided_trait_name=provided_trait_name))
# ---> 25 super().__init__(**kwargs)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:506, in Widget.__init__(self, **kwargs)
#     503 super().__init__(**kwargs)
#     505 Widget._call_widget_constructed(self)
# --> 506 self.open()
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:525, in Widget.open(self)
#     523 """Open a comm to the frontend if one isn't already open."""
#     524 if self.comm is None:
# --> 525     state, buffer_paths, buffers = _remove_buffers(self.get_state())
#     527     args = dict(target_name='jupyter.widget',
#     528                 data={'state': state, 'buffer_paths': buffer_paths},
#     529                 buffers=buffers,
#     530                 metadata={'version': __protocol_version__}
#     531                 )
#     532     if self._model_id is not None:
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:615, in Widget.get_state(self, key, drop_defaults)
#     613 for k in keys:
#     614     to_json = self.trait_metadata(k, 'to_json', self._trait_to_json)
# --> 615     value = to_json(getattr(self, k), self)
#     616     if not drop_defaults or not self._compare(value, traits[k].default_value):
#     617         state[k] = value
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\_serialization.py:68, in serialize_accessor(data, obj)
#      65     return data
#      67 assert isinstance(data, (pa.ChunkedArray, pa.Array))
# ---> 68 validate_accessor_length_matches_table(data, obj.table)
#      69 return serialize_pyarrow_column(data, max_chunksize=obj._rows_per_chunk)
#
# File c:\Users\fauxi\anaconda3\envs\cdp\Lib\site-packages\lonboard\_serialization.py:90, in validate_accessor_length_matches_table(accessor, table)
#      88 def validate_accessor_length_matches_table(accessor, table):
#      89     if len(accessor) != len(table):
# ---> 90         raise TraitError("accessor must have same length as table")
#
# TraitError: accessor must have same length as table

# %% [markdown]
# ## your turn: can you make the above show in 3d?
#
# - see here for some tips: https://developmentseed.org/lonboard/latest/examples/overture-maps/#imports

# %% [markdown]
# # save data

# %%
# save out as fgb using geopandas
# pluto_ogrio.to_file("..Data/nyc_mappluto_24v1_1_shp/mappluto.fgb")

# %%
# ogr.write_dataframe(pluto_ogrio, "../Data/nyc_mappluto_24v1_1_shp/mappluto_ogr.fgb")
